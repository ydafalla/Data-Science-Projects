# %% [markdown]
# ## Cluster Method 2
# #### Feature Engineering using PCA (Principal Component Analysis)

# %%
# %run data_exploration.ipynb
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
le.fit(have_ratings_tags["tag"])
have_ratings_tags['tag']=le.transform(have_ratings_tags["tag"])
from sklearn.decomposition import PCA # Principal Component Analysis module
pca = PCA(n_components=4)
pca_data = pca.fit_transform(have_ratings_tags)

# %%
plt.figure(figsize = (9,7))
plt.scatter(pca_data[:,0],pca_data[:,1], c='goldenrod',alpha=0.8)
plt.show()

# %%
from sklearn.cluster import KMeans
# Set a 3 KMeans clustering
kmeansPCA = KMeans(n_clusters=5)
# Compute cluster centers and predict cluster indices
X_clustered = kmeansPCA.fit_predict(pca_data)

# Define our own color map
LABEL_COLOR_MAP = {0 : 'r',1 : 'g',2 : 'b',3:'y',4:'c'}
label_color = [LABEL_COLOR_MAP[l] for l in X_clustered]

# %%
# Two subplots, the axes array is 1-d
f, axarr = plt.subplots(1,2,figsize = (20,7))
#axarr[0].plot(x, y)
#axarr[0].set_title('Sharing X axis')
#axarr[1].scatter(x, y)

# Plot the scatter digram
#plt.figure(figsize = (20,10))
axarr[0].scatter(pca_data[:,0],pca_data[:,2], c= label_color, alpha=0.7) 
# Plot the scatter digram

axarr[1].scatter(pca_data[:,1],pca_data[:,3], c= label_color, alpha=0.7) 
plt.tight_layout()
plt.show()
