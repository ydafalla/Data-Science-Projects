# %% [markdown]
# ## Feature Engineering
# * First we are going to transforms the tags to numerical values using the transform function

# %%
# %run data_exploration.ipynb
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
le.fit(have_ratings_tags["tag"])
have_ratings_tags['tag']=le.transform(have_ratings_tags["tag"])
have_ratings_tags.head()
# Out:
#    userId  movieId  rating   tag  average_ratings
# 0       2    60756     5.0   510           4.1875
# 1       2    60756     5.0   604           4.1875
# 2       2    60756     5.0  1416           4.1875
# 3      62    60756     3.5   295           4.1875
# 4      62    60756     3.5   510           4.1875

# %%
have_ratings_tags.dtypes
# Out:
# userId               int64
# movieId              int64
# rating             float64
# tag                  int64
# average_ratings    float64
# dtype: object

# %% [markdown]
# * Now we are going to remove the userid field because it is irrelevant

# %%
del have_ratings_tags['userId']

# %% [markdown]
# * Now we are going to check the correlation between features

# %%
import seaborn as sns
have_ratings_tags_temp = have_ratings_tags[['movieId', 'tag','average_ratings']] #Subsetting the data
cor = have_ratings_tags_temp.corr()
sns.heatmap(cor, square = True)

# %% [markdown]
# ## Kmeans clustering

# %%
# Taking sample data set as X
X = have_ratings_tags.iloc[:,[2, 3]].values

from sklearn.cluster import KMeans
wcss =[]

# %% [markdown]
# #### Determine the cluster size

# %%
for i in range (1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter =300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# * From the above plot we can pick the cluster size to be 5

# %%
kmeans=KMeans(n_clusters= 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
Y_Kmeans = kmeans.fit_predict(X)

# %% [markdown]
# #### Visualizing the clusters

# %%
plt.figure(figsize=(10,10))
plt.scatter(X[Y_Kmeans == 0, 0], X[Y_Kmeans == 0,1],s = 10, c='blue', label = 'C1')

plt.scatter(X[Y_Kmeans == 1, 0], X[Y_Kmeans == 1,1],s = 10, c='red', label = 'C2')

plt.scatter(X[Y_Kmeans == 2, 0], X[Y_Kmeans == 2,1],s = 10, c='cyan', label = 'C3')

plt.scatter(X[Y_Kmeans == 3, 0], X[Y_Kmeans == 3,1],s = 10, c='green', label = 'C4')

plt.scatter(X[Y_Kmeans == 4, 0], X[Y_Kmeans == 4,1],s = 10, c='magenta', label = 'C5')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 10, c = 'black', label = 'Centroids')
   
plt.title('Clusters of Movies')
plt.xlabel('Tags')
plt.ylabel('Average Rating')
plt.legend()
plt.show()
