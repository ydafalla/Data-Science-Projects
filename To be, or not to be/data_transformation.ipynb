# %% [markdown]
# ## Data Transformation
# Text data requires preparation before it can be used in predictive modeling. We need to perform tokenization and vectorization of the text data.
#
# #### Tokenization:
# Tokenization is the process of breaking up text into words, keywords, phrases or other elements called tokens.
# Tokens can be individual words, phrases or even whole sentences.
#
# #### Vectorization
# Vectorization refers to encoding words or tokens as integers or floating point values for use as an input to a machine learning algorithm.
#
# I am goint to use the scikit-learn library to perform both tokenization and vectorization.

# %%
# %run data_exploration.ipynb
data_frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111396 entries, 0 to 111395
# Data columns (total 6 columns):
# Dataline            111396 non-null int64
# Play                111396 non-null object
# PlayerLinenumber    111393 non-null float64
# ActSceneLine        105153 non-null object
# Player              111389 non-null object
# PlayerLine          111396 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.1+ MB
# Number of unique plays = 36
#                            Dataline  PlayerLinenumber
# Play
# A Comedy of Errors         48200025           75112.0
# A Midsummer nights dream  156736950           85898.0
# A Winters Tale            382575828          186514.0
# Alls well that ends well   43784766          106670.0
# Antony and Cleopatra       79157483          112274.0
# As you like it             48409999           91439.0
# Coriolanus                105702172          135568.0
# Cymbeline                 120534953          130105.0
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v=TfidfVectorizer()
x=v.fit_transform(data_frame['PlayerLine'])
x.toarray()
#data_frame['PlayerLineScore']=list(x.toarray())
#print(data_frame)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-191927d7fdaa> in <module>
#       2 v=TfidfVectorizer()
#       3 x=v.fit_transform(data_frame['PlayerLine'])
# ----> 4 x.toarray()
#       5 #data_frame['PlayerLineScore']=list(x.toarray())
#       6 #print(data_frame)
#
# /home/anaconda3/lib/python3.7/site-packages/scipy/sparse/compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1026             raise ValueError('Output array must be C or F contiguous')
#
# /home/anaconda3/lib/python3.7/site-packages/scipy/sparse/base.py in _process_toarray_args(self, order, out)
#    1184             return out
#    1185         else:
# ...
